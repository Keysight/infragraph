# %%
from infragraph.translators.lstopo_translator import LstopoParser

# %%
lstopo_xml_file = "/home/amosrai0keys/keysight_codebase/hwloc_to_infragraph/infragraph/src/tests/test_translators/mock_data/supermicro.xml"

# %%
parser = LstopoParser(lstopo_xml_file)
print(parser.parse())
